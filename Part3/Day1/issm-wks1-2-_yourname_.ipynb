# %% [markdown]
# ## **i. Mount google drive**
# ---

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## **ii. Import the libraries**
# ---

# %%
import cv2
import sys
import os
import scipy
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


print("Versions of key libraries")
print("---")
print("numpy:     ", np.__version__)
print("matplotlib:", matplotlib.__version__)
print("pandas:    ", pd.__version__)
print("scipy:     ", scipy.__version__)

# %% [markdown]
# ## **iii. Append /iss/issm/data/ in your python path**
# ---

# %%
sys.path.append('/content/gdrive/My Drive/iss/issm/data/')
print("All the system paths:")
sys.path

# %% [markdown]
# ## **iv. Change working directory to /iss/issm/data/**
# ---

# %%
os.chdir('/content/gdrive/My Drive/iss/issm/data/')
print("Current working directory:")
os.getcwd()

# %% [markdown]
# ## **v. Setup matplotlib**
# ---

# %%
plt.style.use('ggplot')                   # if want to use the default style, set 'classic'
plt.rcParams['ytick.right']     = True
plt.rcParams['ytick.labelright']= True
plt.rcParams['ytick.left']      = False
plt.rcParams['ytick.labelleft'] = False

print("Matplotlib setup completes.")

# %% [markdown]
# ## **1. Part 1: Perform peak detection**
# ---
# * Step 1: Read in the ecg signals
# * Step 2: Perform peak detection
# * Step 3: Display detected peaks

# %%
# Type your code below

# %% [markdown]
# ## **Part 2: Baseline correction with arPLS**
# ---
# * Step 1: Import `Baseline` from `pybaselines`
# * Step 2: Create a fitter and call `Baseline.arpls` on the ECG signal
# * Step 3: Subtract the estimated baseline and display the corrected signal
#
# Start with `lam=1e5`, `max_iter=50`, and `tol=1e-3`. Check `params['tol_history']` to see whether the fitting process converged.

# %%
try:
    from pybaselines import Baseline
except ImportError:
    import subprocess
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'pybaselines'])
    from pybaselines import Baseline

# %%
# Type your code below
